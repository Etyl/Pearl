# %%
import numpy as numpy
import matplotlib.pyplot as plt

# %%
log_loss = []
with open("loss.log","r") as f:
    for line in f:
        log_loss.append(float(line.strip()))

# %%
plt.plot(log_loss)
plt.show()
